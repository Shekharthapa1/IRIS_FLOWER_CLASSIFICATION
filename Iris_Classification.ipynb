# %% [markdown]
# ## Import Libararies

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import model_selection

# %%
from IPython.display import Image
Image(url='https://encrypted-tbn3.gstatic.com/licensed-image?q=tbn:ANd9GcSu7StNvF4ALcDziQdpCaO9lTIZ0qP1zixAhtFETIPuBbmnX0rIxxlZ_pliTF-t-WbEz8lasmltY8xKkQU')
# Out:
# <img src="https://encrypted-tbn3.gstatic.com/licensed-image?q=tbn:ANd9GcSu7StNvF4ALcDziQdpCaO9lTIZ0qP1zixAhtFETIPuBbmnX0rIxxlZ_pliTF-t-WbEz8lasmltY8xKkQU"/>

# %% [markdown]
# ## Import Iris dataset

# %%
iris= pd.read_csv("C:\\Users\\hp\\Documents\\DataSet\\Iris.csv",index_col='Id')
iris.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Analyzing Data

# %%
plt.hist(iris['SepalLengthCm'],color='g',bins=25)
plt.show()

# %%
plt.hist(iris['SepalWidthCm'],color='purple',bins=25)
plt.show()

# %%
plt.hist(iris['PetalLengthCm'],color='brown',bins=25)
plt.show()

# %%
plt.hist(iris['SepalLengthCm'],color='orange',bins=25)
plt.show()

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
import seaborn as sns

# %%
sns.scatterplot(x= iris['SepalLengthCm'],y= iris['PetalLengthCm'],data= iris,hue='Species')
plt.show()

# %%
sns.scatterplot(x= iris['SepalWidthCm'],y= iris['PetalWidthCm'],data= iris,hue='Species')
plt.show()

# %%
irish= iris.drop(['Species'],axis=1)

# %%
sns.heatmap(irish)
plt.show()

# %%
iris.plot(kind='box',subplots=True,sharex=False,sharey=False,layout=(2,3))
plt.show()

# %%
sns.jointplot(iris)
plt.show()

# %%
sns.pairplot(iris,hue='Species')
plt.show()

# %% [markdown]
# ## Train and Test Data

# %%
iris=iris.values

# %%
x = iris[:,0:4]
y= iris[:,4]

# %%
x_train, x_test , y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=10)

# %%
scoring='accuracy'

# %% [markdown]
# ## Accuracy

# %%
models=[]
models.append(('lr',LogisticRegression()))
models.append(('dtc',DecisionTreeCassifier()))
models.append(('nbr',KNeighborsClassifier()))
models.append(('nb',GaussianNB()))
models.append(('svm',SVC()))
results=[]
names=[]
for name, model in models:
    kfold= model_selection.KFold()
    cv_results=model_selection.cross_val_score(model,x_train,y_train,cv=kfold,scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg='%s:%f(%f)' %(name, cv_results.mean(),cv_results.std())
    print(msg)
# Out:
# lr:0.961905(0.035635)
# dtc:0.933333(0.064594)
# nbr:0.942857(0.055533)
# nb:0.923810(0.048562)
# svm:0.952381(0.052164)
